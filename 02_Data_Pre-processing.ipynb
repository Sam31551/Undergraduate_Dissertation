# %% [markdown]
# #Read in Data

# %%
import pandas as pd
data = pd.read_csv('data_cleaned.csv', index_col = 0)
data
# Out:
#        country  season  md                 team     manager       formation  \
# 0      Germany    2004   1  1.FC Kaiserslautern   Kurt Jara  4-4-2 double 6
# 1      Germany    2004   2  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 2      Germany    2004   3  1.FC Kaiserslautern   Kurt Jara         4-2-3-1
# 3      Germany    2004   4  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 4      Germany    2004   5  1.FC Kaiserslautern   Kurt Jara           3-5-2
# ...        ...     ...  ..                  ...         ...             ...
# 67833  Germany    2022  16           RB Leipzig  Marco Rose         4-2-3-1
# 67834  Germany    2022  17           RB Leipzig  Marco Rose           4-4-2
# 67835  Germany    2022  18           RB Leipzig  Marco Rose           4-4-2
# 67836  Germany    2022  19           RB Leipzig  Marco Rose           3-4-3
# 67837  Germany    2022  20           RB Leipzig  Marco Rose           3-4-3
#
#        goals   gd outcome  points           opp_team        opp_manager  \
# 0        1.0 -2.0    loss     0.0     1.FC Nuremberg      Wolfgang Wolf
# 1        1.0 -1.0    loss     0.0      FC Schalke 04      Jupp Heynckes
# 2        2.0 -1.0    loss     0.0      VfB Stuttgart    Matthias Sammer
# 3        3.0  1.0     win     3.0   FC Hansa Rostock       Juri Schlünz
# 4        2.0  1.0     win     3.0       Hamburger SV   Klaus Toppmöller
# ...      ...  ...     ...     ...                ...                ...
# 67833    1.0  0.0    draw     1.0      Bayern Munich  Julian Nagelsmann
# 67834    6.0  5.0     win     3.0      FC Schalke 04        Thomas Reis
# 67835    2.0  1.0     win     3.0      VfB Stuttgart     Bruno Labbadia
# 67836    0.0  0.0    draw     1.0         1. FC Köln   Steffen Baumgart
# 67837    1.0 -1.0    loss     0.0  1.FC Union Berlin        Urs Fischer
#
#          opp_formation  opp_goals  opp_gd opp_outcome  opp_points  \
# 0        4-4-2 Diamond        3.0     2.0         win         3.0
# 1                3-5-2        2.0     1.0         win         3.0
# 2        4-4-2 Diamond        3.0     1.0         win         3.0
# 3                5-3-2        2.0    -1.0        loss         0.0
# 4                3-5-2        1.0    -1.0        loss         0.0
# ...                ...        ...     ...         ...         ...
# 67833          4-2-3-1        1.0     0.0        draw         1.0
# 67834          4-2-3-1        1.0    -5.0        loss         0.0
# 67835  4-3-3 Attacking        1.0    -1.0        loss         0.0
# 67836          4-2-3-1        0.0     0.0        draw         1.0
# 67837  3-5-2 Attacking        2.0     1.0         win         3.0
#
#        avg_starter_age  total_starter_value
# 0            27.818182                15.95
# 1            28.000000                16.50
# 2            27.333333                14.20
# 3            26.928571                17.95
# 4            26.428571                17.65
# ...                ...                  ...
# 67833        26.272727               276.00
# 67834        26.090909               279.00
# 67835        25.454545               290.00
# 67836        25.636364               275.00
# 67837              NaN                  NaN
#
# [67838 rows x 19 columns]

# %%
#Need to drop rows where target variable = null
data = data[data['total_starter_value'].notna()]
data
# Out:
#        country  season  md                 team     manager       formation  \
# 0      Germany    2004   1  1.FC Kaiserslautern   Kurt Jara  4-4-2 double 6
# 1      Germany    2004   2  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 2      Germany    2004   3  1.FC Kaiserslautern   Kurt Jara         4-2-3-1
# 3      Germany    2004   4  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 4      Germany    2004   5  1.FC Kaiserslautern   Kurt Jara           3-5-2
# ...        ...     ...  ..                  ...         ...             ...
# 67832  Germany    2022  15           RB Leipzig  Marco Rose           4-4-2
# 67833  Germany    2022  16           RB Leipzig  Marco Rose         4-2-3-1
# 67834  Germany    2022  17           RB Leipzig  Marco Rose           4-4-2
# 67835  Germany    2022  18           RB Leipzig  Marco Rose           4-4-2
# 67836  Germany    2022  19           RB Leipzig  Marco Rose           3-4-3
#
#        goals   gd outcome  points          opp_team        opp_manager  \
# 0        1.0 -2.0    loss     0.0    1.FC Nuremberg      Wolfgang Wolf
# 1        1.0 -1.0    loss     0.0     FC Schalke 04      Jupp Heynckes
# 2        2.0 -1.0    loss     0.0     VfB Stuttgart    Matthias Sammer
# 3        3.0  1.0     win     3.0  FC Hansa Rostock       Juri Schlünz
# 4        2.0  1.0     win     3.0      Hamburger SV   Klaus Toppmöller
# ...      ...  ...     ...     ...               ...                ...
# 67832    2.0  1.0     win     3.0  SV Werder Bremen         Ole Werner
# 67833    1.0  0.0    draw     1.0     Bayern Munich  Julian Nagelsmann
# 67834    6.0  5.0     win     3.0     FC Schalke 04        Thomas Reis
# 67835    2.0  1.0     win     3.0     VfB Stuttgart     Bruno Labbadia
# 67836    0.0  0.0    draw     1.0        1. FC Köln   Steffen Baumgart
#
#          opp_formation  opp_goals  opp_gd opp_outcome  opp_points  \
# 0        4-4-2 Diamond        3.0     2.0         win         3.0
# 1                3-5-2        2.0     1.0         win         3.0
# 2        4-4-2 Diamond        3.0     1.0         win         3.0
# 3                5-3-2        2.0    -1.0        loss         0.0
# 4                3-5-2        1.0    -1.0        loss         0.0
# ...                ...        ...     ...         ...         ...
# 67832          3-1-4-2        1.0    -1.0        loss         0.0
# 67833          4-2-3-1        1.0     0.0        draw         1.0
# 67834          4-2-3-1        1.0    -5.0        loss         0.0
# 67835  4-3-3 Attacking        1.0    -1.0        loss         0.0
# 67836          4-2-3-1        0.0     0.0        draw         1.0
#
#        avg_starter_age  total_starter_value
# 0            27.818182                15.95
# 1            28.000000                16.50
# 2            27.333333                14.20
# 3            26.928571                17.95
# 4            26.428571                17.65
# ...                ...                  ...
# 67832        25.333333               314.20
# 67833        26.272727               276.00
# 67834        26.090909               279.00
# 67835        25.454545               290.00
# 67836        25.636364               275.00
#
# [66234 rows x 19 columns]

# %%
data.isnull().sum()
# Out:
# country                   0
# season                    0
# md                        0
# team                      0
# manager                  13
# formation              3062
# goals                     0
# gd                        0
# outcome                   0
# points                    0
# opp_team                  0
# opp_manager              13
# opp_formation          3062
# opp_goals                 0
# opp_gd                    0
# opp_outcome               0
# opp_points                0
# avg_starter_age           3
# total_starter_value       0
# dtype: int64

# %%
#drop AC Ajaccio season 2005 from table as they arte missing manager and formations from data
data = data[data.manager.notnull()]
data
# Out:
#        country  season  md                 team     manager       formation  \
# 0      Germany    2004   1  1.FC Kaiserslautern   Kurt Jara  4-4-2 double 6
# 1      Germany    2004   2  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 2      Germany    2004   3  1.FC Kaiserslautern   Kurt Jara         4-2-3-1
# 3      Germany    2004   4  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 4      Germany    2004   5  1.FC Kaiserslautern   Kurt Jara           3-5-2
# ...        ...     ...  ..                  ...         ...             ...
# 67832  Germany    2022  15           RB Leipzig  Marco Rose           4-4-2
# 67833  Germany    2022  16           RB Leipzig  Marco Rose         4-2-3-1
# 67834  Germany    2022  17           RB Leipzig  Marco Rose           4-4-2
# 67835  Germany    2022  18           RB Leipzig  Marco Rose           4-4-2
# 67836  Germany    2022  19           RB Leipzig  Marco Rose           3-4-3
#
#        goals   gd outcome  points          opp_team        opp_manager  \
# 0        1.0 -2.0    loss     0.0    1.FC Nuremberg      Wolfgang Wolf
# 1        1.0 -1.0    loss     0.0     FC Schalke 04      Jupp Heynckes
# 2        2.0 -1.0    loss     0.0     VfB Stuttgart    Matthias Sammer
# 3        3.0  1.0     win     3.0  FC Hansa Rostock       Juri Schlünz
# 4        2.0  1.0     win     3.0      Hamburger SV   Klaus Toppmöller
# ...      ...  ...     ...     ...               ...                ...
# 67832    2.0  1.0     win     3.0  SV Werder Bremen         Ole Werner
# 67833    1.0  0.0    draw     1.0     Bayern Munich  Julian Nagelsmann
# 67834    6.0  5.0     win     3.0     FC Schalke 04        Thomas Reis
# 67835    2.0  1.0     win     3.0     VfB Stuttgart     Bruno Labbadia
# 67836    0.0  0.0    draw     1.0        1. FC Köln   Steffen Baumgart
#
#          opp_formation  opp_goals  opp_gd opp_outcome  opp_points  \
# 0        4-4-2 Diamond        3.0     2.0         win         3.0
# 1                3-5-2        2.0     1.0         win         3.0
# 2        4-4-2 Diamond        3.0     1.0         win         3.0
# 3                5-3-2        2.0    -1.0        loss         0.0
# 4                3-5-2        1.0    -1.0        loss         0.0
# ...                ...        ...     ...         ...         ...
# 67832          3-1-4-2        1.0    -1.0        loss         0.0
# 67833          4-2-3-1        1.0     0.0        draw         1.0
# 67834          4-2-3-1        1.0    -5.0        loss         0.0
# 67835  4-3-3 Attacking        1.0    -1.0        loss         0.0
# 67836          4-2-3-1        0.0     0.0        draw         1.0
#
#        avg_starter_age  total_starter_value
# 0            27.818182                15.95
# 1            28.000000                16.50
# 2            27.333333                14.20
# 3            26.928571                17.95
# 4            26.428571                17.65
# ...                ...                  ...
# 67832        25.333333               314.20
# 67833        26.272727               276.00
# 67834        26.090909               279.00
# 67835        25.454545               290.00
# 67836        25.636364               275.00
#
# [66221 rows x 19 columns]

# %%
data = data[data.opp_manager.notnull()]
data
# Out:
#        country  season  md                 team     manager       formation  \
# 0      Germany    2004   1  1.FC Kaiserslautern   Kurt Jara  4-4-2 double 6
# 1      Germany    2004   2  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 2      Germany    2004   3  1.FC Kaiserslautern   Kurt Jara         4-2-3-1
# 3      Germany    2004   4  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 4      Germany    2004   5  1.FC Kaiserslautern   Kurt Jara           3-5-2
# ...        ...     ...  ..                  ...         ...             ...
# 67832  Germany    2022  15           RB Leipzig  Marco Rose           4-4-2
# 67833  Germany    2022  16           RB Leipzig  Marco Rose         4-2-3-1
# 67834  Germany    2022  17           RB Leipzig  Marco Rose           4-4-2
# 67835  Germany    2022  18           RB Leipzig  Marco Rose           4-4-2
# 67836  Germany    2022  19           RB Leipzig  Marco Rose           3-4-3
#
#        goals   gd outcome  points          opp_team        opp_manager  \
# 0        1.0 -2.0    loss     0.0    1.FC Nuremberg      Wolfgang Wolf
# 1        1.0 -1.0    loss     0.0     FC Schalke 04      Jupp Heynckes
# 2        2.0 -1.0    loss     0.0     VfB Stuttgart    Matthias Sammer
# 3        3.0  1.0     win     3.0  FC Hansa Rostock       Juri Schlünz
# 4        2.0  1.0     win     3.0      Hamburger SV   Klaus Toppmöller
# ...      ...  ...     ...     ...               ...                ...
# 67832    2.0  1.0     win     3.0  SV Werder Bremen         Ole Werner
# 67833    1.0  0.0    draw     1.0     Bayern Munich  Julian Nagelsmann
# 67834    6.0  5.0     win     3.0     FC Schalke 04        Thomas Reis
# 67835    2.0  1.0     win     3.0     VfB Stuttgart     Bruno Labbadia
# 67836    0.0  0.0    draw     1.0        1. FC Köln   Steffen Baumgart
#
#          opp_formation  opp_goals  opp_gd opp_outcome  opp_points  \
# 0        4-4-2 Diamond        3.0     2.0         win         3.0
# 1                3-5-2        2.0     1.0         win         3.0
# 2        4-4-2 Diamond        3.0     1.0         win         3.0
# 3                5-3-2        2.0    -1.0        loss         0.0
# 4                3-5-2        1.0    -1.0        loss         0.0
# ...                ...        ...     ...         ...         ...
# 67832          3-1-4-2        1.0    -1.0        loss         0.0
# 67833          4-2-3-1        1.0     0.0        draw         1.0
# 67834          4-2-3-1        1.0    -5.0        loss         0.0
# 67835  4-3-3 Attacking        1.0    -1.0        loss         0.0
# 67836          4-2-3-1        0.0     0.0        draw         1.0
#
#        avg_starter_age  total_starter_value
# 0            27.818182                15.95
# 1            28.000000                16.50
# 2            27.333333                14.20
# 3            26.928571                17.95
# 4            26.428571                17.65
# ...                ...                  ...
# 67832        25.333333               314.20
# 67833        26.272727               276.00
# 67834        26.090909               279.00
# 67835        25.454545               290.00
# 67836        25.636364               275.00
#
# [66208 rows x 19 columns]

# %%
data[data['avg_starter_age'].isna()]
# Out:
#        country  season  md               team            manager  \
# 8704   England    2018  38       Liverpool FC       Jürgen Klopp
# 23666  England    2011  38    Manchester City    Roberto Mancini
# 47701  England    2006  38  Manchester United  Sir Alex Ferguson
#
#              formation  goals   gd outcome  points                 opp_team  \
# 8704   4-3-3 Attacking    2.0  2.0     win     3.0  Wolverhampton Wanderers
# 23666          4-2-3-1    3.0  1.0     win     3.0      Queens Park Rangers
# 47701              NaN    0.0 -1.0    loss     0.0          West Ham United
#
#                opp_manager   opp_formation  opp_goals  opp_gd opp_outcome  \
# 8704   Nuno Espírito Santo      3-5-2 flat        0.0    -2.0        loss
# 23666          Mark Hughes  4-4-2 double 6        2.0    -1.0        loss
# 47701      Alan Curbishley             NaN        1.0     1.0         win
#
#        opp_points  avg_starter_age  total_starter_value
# 8704          0.0              NaN                  0.0
# 23666         0.0              NaN                  0.0
# 47701         3.0              NaN                  0.0

# %%
#Replace with previous values
data['avg_starter_age'].fillna(method='pad', inplace=True)
data
# Out:
# <ipython-input-21-61d58d95514e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['avg_starter_age'].fillna(method='pad', inplace=True)
#        country  season  md                 team     manager       formation  \
# 0      Germany    2004   1  1.FC Kaiserslautern   Kurt Jara  4-4-2 double 6
# 1      Germany    2004   2  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 2      Germany    2004   3  1.FC Kaiserslautern   Kurt Jara         4-2-3-1
# 3      Germany    2004   4  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 4      Germany    2004   5  1.FC Kaiserslautern   Kurt Jara           3-5-2
# ...        ...     ...  ..                  ...         ...             ...
# 67832  Germany    2022  15           RB Leipzig  Marco Rose           4-4-2
# 67833  Germany    2022  16           RB Leipzig  Marco Rose         4-2-3-1
# 67834  Germany    2022  17           RB Leipzig  Marco Rose           4-4-2
# 67835  Germany    2022  18           RB Leipzig  Marco Rose           4-4-2
# 67836  Germany    2022  19           RB Leipzig  Marco Rose           3-4-3
#
#        goals   gd outcome  points          opp_team        opp_manager  \
# 0        1.0 -2.0    loss     0.0    1.FC Nuremberg      Wolfgang Wolf
# 1        1.0 -1.0    loss     0.0     FC Schalke 04      Jupp Heynckes
# 2        2.0 -1.0    loss     0.0     VfB Stuttgart    Matthias Sammer
# 3        3.0  1.0     win     3.0  FC Hansa Rostock       Juri Schlünz
# 4        2.0  1.0     win     3.0      Hamburger SV   Klaus Toppmöller
# ...      ...  ...     ...     ...               ...                ...
# 67832    2.0  1.0     win     3.0  SV Werder Bremen         Ole Werner
# 67833    1.0  0.0    draw     1.0     Bayern Munich  Julian Nagelsmann
# 67834    6.0  5.0     win     3.0     FC Schalke 04        Thomas Reis
# 67835    2.0  1.0     win     3.0     VfB Stuttgart     Bruno Labbadia
# 67836    0.0  0.0    draw     1.0        1. FC Köln   Steffen Baumgart
#
#          opp_formation  opp_goals  opp_gd opp_outcome  opp_points  \
# 0        4-4-2 Diamond        3.0     2.0         win         3.0
# 1                3-5-2        2.0     1.0         win         3.0
# 2        4-4-2 Diamond        3.0     1.0         win         3.0
# 3                5-3-2        2.0    -1.0        loss         0.0
# 4                3-5-2        1.0    -1.0        loss         0.0
# ...                ...        ...     ...         ...         ...
# 67832          3-1-4-2        1.0    -1.0        loss         0.0
# 67833          4-2-3-1        1.0     0.0        draw         1.0
# 67834          4-2-3-1        1.0    -5.0        loss         0.0
# 67835  4-3-3 Attacking        1.0    -1.0        loss         0.0
# 67836          4-2-3-1        0.0     0.0        draw         1.0
#
#        avg_starter_age  total_starter_value
# 0            27.818182                15.95
# 1            28.000000                16.50
# 2            27.333333                14.20
# 3            26.928571                17.95
# 4            26.428571                17.65
# ...                ...                  ...
# 67832        25.333333               314.20
# 67833        26.272727               276.00
# 67834        26.090909               279.00
# 67835        25.454545               290.00
# 67836        25.636364               275.00
#
# [66208 rows x 19 columns]

# %%
data.isnull().sum()
# Out:
# country                   0
# season                    0
# md                        0
# team                      0
# manager                   0
# formation              3046
# goals                     0
# gd                        0
# outcome                   0
# points                    0
# opp_team                  0
# opp_manager               0
# opp_formation          3046
# opp_goals                 0
# opp_gd                    0
# opp_outcome               0
# opp_points                0
# avg_starter_age           0
# total_starter_value       0
# dtype: int64

# %%
data[data['formation'].isna()].season.unique()
# Out:
# array([2006, 2007, 2008, 2009, 2012, 2004, 2005, 2010, 2011, 2017])

# %%
data[data['opp_formation'].isna()].season.unique()
# Out:
# array([2009, 2004, 2005, 2006, 2007, 2008, 2012, 2017, 2010, 2011])

# %%
data = data[data.formation.notnull()]
data
# Out:
#        country  season  md                 team     manager       formation  \
# 0      Germany    2004   1  1.FC Kaiserslautern   Kurt Jara  4-4-2 double 6
# 1      Germany    2004   2  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 2      Germany    2004   3  1.FC Kaiserslautern   Kurt Jara         4-2-3-1
# 3      Germany    2004   4  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 4      Germany    2004   5  1.FC Kaiserslautern   Kurt Jara           3-5-2
# ...        ...     ...  ..                  ...         ...             ...
# 67832  Germany    2022  15           RB Leipzig  Marco Rose           4-4-2
# 67833  Germany    2022  16           RB Leipzig  Marco Rose         4-2-3-1
# 67834  Germany    2022  17           RB Leipzig  Marco Rose           4-4-2
# 67835  Germany    2022  18           RB Leipzig  Marco Rose           4-4-2
# 67836  Germany    2022  19           RB Leipzig  Marco Rose           3-4-3
#
#        goals   gd outcome  points          opp_team        opp_manager  \
# 0        1.0 -2.0    loss     0.0    1.FC Nuremberg      Wolfgang Wolf
# 1        1.0 -1.0    loss     0.0     FC Schalke 04      Jupp Heynckes
# 2        2.0 -1.0    loss     0.0     VfB Stuttgart    Matthias Sammer
# 3        3.0  1.0     win     3.0  FC Hansa Rostock       Juri Schlünz
# 4        2.0  1.0     win     3.0      Hamburger SV   Klaus Toppmöller
# ...      ...  ...     ...     ...               ...                ...
# 67832    2.0  1.0     win     3.0  SV Werder Bremen         Ole Werner
# 67833    1.0  0.0    draw     1.0     Bayern Munich  Julian Nagelsmann
# 67834    6.0  5.0     win     3.0     FC Schalke 04        Thomas Reis
# 67835    2.0  1.0     win     3.0     VfB Stuttgart     Bruno Labbadia
# 67836    0.0  0.0    draw     1.0        1. FC Köln   Steffen Baumgart
#
#          opp_formation  opp_goals  opp_gd opp_outcome  opp_points  \
# 0        4-4-2 Diamond        3.0     2.0         win         3.0
# 1                3-5-2        2.0     1.0         win         3.0
# 2        4-4-2 Diamond        3.0     1.0         win         3.0
# 3                5-3-2        2.0    -1.0        loss         0.0
# 4                3-5-2        1.0    -1.0        loss         0.0
# ...                ...        ...     ...         ...         ...
# 67832          3-1-4-2        1.0    -1.0        loss         0.0
# 67833          4-2-3-1        1.0     0.0        draw         1.0
# 67834          4-2-3-1        1.0    -5.0        loss         0.0
# 67835  4-3-3 Attacking        1.0    -1.0        loss         0.0
# 67836          4-2-3-1        0.0     0.0        draw         1.0
#
#        avg_starter_age  total_starter_value
# 0            27.818182                15.95
# 1            28.000000                16.50
# 2            27.333333                14.20
# 3            26.928571                17.95
# 4            26.428571                17.65
# ...                ...                  ...
# 67832        25.333333               314.20
# 67833        26.272727               276.00
# 67834        26.090909               279.00
# 67835        25.454545               290.00
# 67836        25.636364               275.00
#
# [63162 rows x 19 columns]

# %%
data = data[data.opp_formation.notnull()]
data
# Out:
#        country  season  md                 team     manager       formation  \
# 0      Germany    2004   1  1.FC Kaiserslautern   Kurt Jara  4-4-2 double 6
# 1      Germany    2004   2  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 2      Germany    2004   3  1.FC Kaiserslautern   Kurt Jara         4-2-3-1
# 3      Germany    2004   4  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 4      Germany    2004   5  1.FC Kaiserslautern   Kurt Jara           3-5-2
# ...        ...     ...  ..                  ...         ...             ...
# 67832  Germany    2022  15           RB Leipzig  Marco Rose           4-4-2
# 67833  Germany    2022  16           RB Leipzig  Marco Rose         4-2-3-1
# 67834  Germany    2022  17           RB Leipzig  Marco Rose           4-4-2
# 67835  Germany    2022  18           RB Leipzig  Marco Rose           4-4-2
# 67836  Germany    2022  19           RB Leipzig  Marco Rose           3-4-3
#
#        goals   gd outcome  points          opp_team        opp_manager  \
# 0        1.0 -2.0    loss     0.0    1.FC Nuremberg      Wolfgang Wolf
# 1        1.0 -1.0    loss     0.0     FC Schalke 04      Jupp Heynckes
# 2        2.0 -1.0    loss     0.0     VfB Stuttgart    Matthias Sammer
# 3        3.0  1.0     win     3.0  FC Hansa Rostock       Juri Schlünz
# 4        2.0  1.0     win     3.0      Hamburger SV   Klaus Toppmöller
# ...      ...  ...     ...     ...               ...                ...
# 67832    2.0  1.0     win     3.0  SV Werder Bremen         Ole Werner
# 67833    1.0  0.0    draw     1.0     Bayern Munich  Julian Nagelsmann
# 67834    6.0  5.0     win     3.0     FC Schalke 04        Thomas Reis
# 67835    2.0  1.0     win     3.0     VfB Stuttgart     Bruno Labbadia
# 67836    0.0  0.0    draw     1.0        1. FC Köln   Steffen Baumgart
#
#          opp_formation  opp_goals  opp_gd opp_outcome  opp_points  \
# 0        4-4-2 Diamond        3.0     2.0         win         3.0
# 1                3-5-2        2.0     1.0         win         3.0
# 2        4-4-2 Diamond        3.0     1.0         win         3.0
# 3                5-3-2        2.0    -1.0        loss         0.0
# 4                3-5-2        1.0    -1.0        loss         0.0
# ...                ...        ...     ...         ...         ...
# 67832          3-1-4-2        1.0    -1.0        loss         0.0
# 67833          4-2-3-1        1.0     0.0        draw         1.0
# 67834          4-2-3-1        1.0    -5.0        loss         0.0
# 67835  4-3-3 Attacking        1.0    -1.0        loss         0.0
# 67836          4-2-3-1        0.0     0.0        draw         1.0
#
#        avg_starter_age  total_starter_value
# 0            27.818182                15.95
# 1            28.000000                16.50
# 2            27.333333                14.20
# 3            26.928571                17.95
# 4            26.428571                17.65
# ...                ...                  ...
# 67832        25.333333               314.20
# 67833        26.272727               276.00
# 67834        26.090909               279.00
# 67835        25.454545               290.00
# 67836        25.636364               275.00
#
# [62889 rows x 19 columns]

# %%
data.isnull().sum()
# Out:
# country                0
# season                 0
# md                     0
# team                   0
# manager                0
# formation              0
# goals                  0
# gd                     0
# outcome                0
# points                 0
# opp_team               0
# opp_manager            0
# opp_formation          0
# opp_goals              0
# opp_gd                 0
# opp_outcome            0
# opp_points             0
# avg_starter_age        0
# total_starter_value    0
# dtype: int64

# %%
data
# Out:
#        country  season  md                 team     manager       formation  \
# 0      Germany    2004   1  1.FC Kaiserslautern   Kurt Jara  4-4-2 double 6
# 1      Germany    2004   2  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 2      Germany    2004   3  1.FC Kaiserslautern   Kurt Jara         4-2-3-1
# 3      Germany    2004   4  1.FC Kaiserslautern   Kurt Jara           3-5-2
# 4      Germany    2004   5  1.FC Kaiserslautern   Kurt Jara           3-5-2
# ...        ...     ...  ..                  ...         ...             ...
# 67832  Germany    2022  15           RB Leipzig  Marco Rose           4-4-2
# 67833  Germany    2022  16           RB Leipzig  Marco Rose         4-2-3-1
# 67834  Germany    2022  17           RB Leipzig  Marco Rose           4-4-2
# 67835  Germany    2022  18           RB Leipzig  Marco Rose           4-4-2
# 67836  Germany    2022  19           RB Leipzig  Marco Rose           3-4-3
#
#        goals   gd outcome  points          opp_team        opp_manager  \
# 0        1.0 -2.0    loss     0.0    1.FC Nuremberg      Wolfgang Wolf
# 1        1.0 -1.0    loss     0.0     FC Schalke 04      Jupp Heynckes
# 2        2.0 -1.0    loss     0.0     VfB Stuttgart    Matthias Sammer
# 3        3.0  1.0     win     3.0  FC Hansa Rostock       Juri Schlünz
# 4        2.0  1.0     win     3.0      Hamburger SV   Klaus Toppmöller
# ...      ...  ...     ...     ...               ...                ...
# 67832    2.0  1.0     win     3.0  SV Werder Bremen         Ole Werner
# 67833    1.0  0.0    draw     1.0     Bayern Munich  Julian Nagelsmann
# 67834    6.0  5.0     win     3.0     FC Schalke 04        Thomas Reis
# 67835    2.0  1.0     win     3.0     VfB Stuttgart     Bruno Labbadia
# 67836    0.0  0.0    draw     1.0        1. FC Köln   Steffen Baumgart
#
#          opp_formation  opp_goals  opp_gd opp_outcome  opp_points  \
# 0        4-4-2 Diamond        3.0     2.0         win         3.0
# 1                3-5-2        2.0     1.0         win         3.0
# 2        4-4-2 Diamond        3.0     1.0         win         3.0
# 3                5-3-2        2.0    -1.0        loss         0.0
# 4                3-5-2        1.0    -1.0        loss         0.0
# ...                ...        ...     ...         ...         ...
# 67832          3-1-4-2        1.0    -1.0        loss         0.0
# 67833          4-2-3-1        1.0     0.0        draw         1.0
# 67834          4-2-3-1        1.0    -5.0        loss         0.0
# 67835  4-3-3 Attacking        1.0    -1.0        loss         0.0
# 67836          4-2-3-1        0.0     0.0        draw         1.0
#
#        avg_starter_age  total_starter_value
# 0            27.818182                15.95
# 1            28.000000                16.50
# 2            27.333333                14.20
# 3            26.928571                17.95
# 4            26.428571                17.65
# ...                ...                  ...
# 67832        25.333333               314.20
# 67833        26.272727               276.00
# 67834        26.090909               279.00
# 67835        25.454545               290.00
# 67836        25.636364               275.00
#
# [62889 rows x 19 columns]

# %%
data.to_csv('data_pre_processed.csv')
